# %% [markdown]
# # Import all necessary libraries and data sets

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### In the next step I import all tables for a certain quarter (Q3/2023) and city (Munich) to understand the data base.

# %%
#def import_data(import_folder)
m_2309_lst = pd.read_csv('input/munich_2309/listings.csv')
m_2309_ngb = pd.read_csv('input/munich_2309/neighbourhoods.csv')
m_2309_rvw = pd.read_csv('input/munich_2309/reviews.csv')

m_2309_cal = pd.read_csv('input/munich_2309/calendar.csv.gz', compression='gzip')
m_2309_lst2 = pd.read_csv('input/munich_2309/listings.csv.gz', compression='gzip')
m_2309_rvw2 = pd.read_csv('input/munich_2309/reviews.csv.gz', compression='gzip')

m_2309_geo = gpd.read_file('input/munich_2309/neighbourhoods.geojson')

df_list = [m_2309_lst, m_2309_lst2, m_2309_rvw, m_2309_rvw2, m_2309_cal, m_2309_ngb, m_2309_geo]

# %%
m_2309_lst.head(3)
# Out:
#        id                                               name  host_id  \
# 0   97945  Rental unit in Munich · ★4.84 · 1 bedroom · 1 ...   517685
# 1  114695  Rental unit in Munich · ★4.80 · 1 bedroom · 3 ...   581737
# 2  127383  Rental unit in Munich · ★4.83 · 1 bedroom · 1 ...   630556
#
#   host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0  Angelika                  NaN        Hadern  48.11492   11.48954
# 1   Stephan                  NaN  Berg am Laim  48.12071   11.63758
# 2     Sonja                  NaN   Maxvorstadt  48.15199   11.56482
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     97               2                129  2019-10-03
# 1  Entire home/apt    111               1                 60  2023-09-19
# 2  Entire home/apt    120               3                108  2023-07-29
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.88                               2                89
# 1               0.40                               3               106
# 2               0.72                               1                 0
#
#    number_of_reviews_ltm license
# 0                      0     NaN
# 1                      5     NaN
# 2                      1     NaN

# %%
m_2309_lst2.head(3)
# Out:
#           id                          listing_url       scrape_id  \
# 1504   97945   https://www.airbnb.com/rooms/97945  20230922223227
# 2190  114695  https://www.airbnb.com/rooms/114695  20230922223227
# 6030  127383  https://www.airbnb.com/rooms/127383  20230922223227
#
#      last_scraped           source  \
# 1504   2023-09-23      city scrape
# 2190   2023-09-23      city scrape
# 6030   2023-09-23  previous scrape
#
#                                                    name  \
# 1504  Rental unit in Munich · ★4.84 · 1 bedroom · 1 ...
# 2190  Rental unit in Munich · ★4.80 · 1 bedroom · 3 ...
# 6030  Rental unit in Munich · ★4.83 · 1 bedroom · 1 ...
#
#                                             description  \
# 1504  <b>The space</b><br />We offer a modern, quiet...
# 2190  <b>The space</b><br />It´s a quiet and sunny a...
# 6030  <b>The space</b><br />My cosy apartment is loc...
#
#                                   neighborhood_overview  \
# 1504  We are living in a outskirt of Munich its call...
# 2190                                                NaN
# 6030                                                NaN
#
#                                             picture_url  host_id  \
# 1504  https://a0.muscache.com/pictures/2459996/10b4c...   517685
# 2190  https://a0.muscache.com/pictures/21571874/960e...   581737
# 6030  https://a0.muscache.com/pictures/79238c11-bc61...   630556
#
#                                       host_url host_name  host_since  \
# 1504  https://www.airbnb.com/users/show/517685  Angelika  2011-04-18
# 2190  https://www.airbnb.com/users/show/581737   Stephan  2011-05-12
# 6030  https://www.airbnb.com/users/show/630556     Sonja  2011-05-26
#
#         host_location                                         host_about  \
# 1504  Munich, Germany  Ich freue mich auf viele internationale Gäste!...
# 2190  Munich, Germany  I am looking forward to meet interesting peopl...
# 6030  Munich, Germany  Hi, mein Name ist Sonja und ich freue mich net...
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 1504       within a day                75%                   0%
# 2190     within an hour               100%                  86%
# 6030     within an hour               100%                  75%
#
#      host_is_superhost                                 host_thumbnail_url  \
# 1504                 f  https://a0.muscache.com/im/users/517685/profil...
# 2190                 t  https://a0.muscache.com/im/users/581737/profil...
# 6030                 f  https://a0.muscache.com/im/users/630556/profil...
#
#                                        host_picture_url host_neighbourhood  \
# 1504  https://a0.muscache.com/im/users/517685/profil...             Hadern
# 2190  https://a0.muscache.com/im/users/581737/profil...       Berg am Laim
# 6030  https://a0.muscache.com/im/users/630556/profil...        Maxvorstadt
#
#       host_listings_count  host_total_listings_count  \
# 1504                    2                          3
# 2190                    3                          3
# 6030                    2                          2
#
#                     host_verifications host_has_profile_pic  \
# 1504                ['email', 'phone']                    t
# 2190                ['email', 'phone']                    t
# 6030  ['email', 'phone', 'work_email']                    t
#
#      host_identity_verified             neighbourhood neighbourhood_cleansed  \
# 1504                      t  Munich, Bavaria, Germany                 Hadern
# 2190                      t                       NaN           Berg am Laim
# 6030                      t                       NaN            Maxvorstadt
#
#       neighbourhood_group_cleansed  latitude  longitude       property_type  \
# 1504                           NaN  48.11492   11.48954  Entire rental unit
# 2190                           NaN  48.12071   11.63758  Entire rental unit
# 6030                           NaN  48.15199   11.56482  Entire rental unit
#
#             room_type  accommodates  bathrooms bathrooms_text  bedrooms  beds  \
# 1504  Entire home/apt             2        NaN         1 bath       1.0   1.0
# 2190  Entire home/apt             5        NaN         1 bath       1.0   3.0
# 6030  Entire home/apt             4        NaN         1 bath       1.0   1.0
#
#                                               amenities    price  \
# 1504  ["Heating", "Paid dryer", "Oven", "Room-darken...   $97.00
# 2190  ["Heating", "Oven", "Smoke alarm", "Cooking ba...  $111.00
# 6030  ["Heating", "Breakfast", "Private patio or bal...  $120.00
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# 1504               2              90                       2
# 2190               1              30                       1
# 6030               3              14                       3
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 1504                       2                      90                      90
# 2190                       1                      30                      30
# 6030                       3                      14                      14
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 1504                     2.0                    90.0               NaN
# 2190                     1.0                    30.0               NaN
# 6030                     3.0                    14.0               NaN
#
#      has_availability  availability_30  availability_60  availability_90  \
# 1504                t                1                1                1
# 2190                t               18               27               27
# 6030                t                0                0                0
#
#       availability_365 calendar_last_scraped  number_of_reviews  \
# 1504                89            2023-09-23                129
# 2190               106            2023-09-23                 60
# 6030                 0            2023-09-23                108
#
#       number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 1504                      0                       0   2011-10-03  2019-10-03
# 2190                      5                       1   2011-07-08  2023-09-19
# 6030                      1                       0   2011-06-04  2023-07-29
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 1504                  4.84                    4.89                       4.82
# 2190                  4.80                    4.75                       4.97
# 6030                  4.83                    4.91                       4.79
#
#       review_scores_checkin  review_scores_communication  \
# 1504                   4.90                         4.93
# 2190                   4.97                         5.00
# 6030                   4.98                         4.95
#
#       review_scores_location  review_scores_value license instant_bookable  \
# 1504                    4.78                 4.73     NaN                f
# 2190                    4.58                 4.60     NaN                f
# 6030                    4.91                 4.79     NaN                f
#
#       calculated_host_listings_count  \
# 1504                               2
# 2190                               3
# 6030                               1
#
#       calculated_host_listings_count_entire_homes  \
# 1504                                            2
# 2190                                            3
# 6030                                            1
#
#       calculated_host_listings_count_private_rooms  \
# 1504                                             0
# 2190                                             0
# 6030                                             0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 1504                                            0               0.88
# 2190                                            0               0.40
# 6030                                            0               0.72

# %%
m_2309_rvw.head(3)
# Out:
#    listing_id        date
# 0       97945  2011-10-03
# 1       97945  2011-12-20
# 2       97945  2012-03-02

# %%
m_2309_rvw2.head(3)
# Out:
#    listing_id      id        date  reviewer_id   reviewer_name  \
# 0       97945  591337  2011-10-03       508190          Lauren
# 1       97945  796084  2011-12-20       341171  Marty & Evelyn
# 2       97945  964528  2012-03-02      1647967             Sue
#
#                                             comments
# 0  We very much enjoyed staying at Angelika's apa...
# 1  Angelika was a very gracious host, and went ou...
# 2  The apartment was beautiful and Angelika provi...

# %%
m_2309_cal.head(3)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       97945  2023-09-23         f  $120.00        $120.00               2
# 1       97945  2023-09-24         f  $120.00        $120.00               2
# 2       97945  2023-09-25         t  $120.00        $120.00               2
#
#    maximum_nights
# 0              90
# 1              90
# 2              90

# %%
m_2309_ngb.head(3)
#m_2309_ngb.value_counts
# Out:
#    neighbourhood_group               neighbourhood
# 0                  NaN         Allach-Untermenzing
# 1                  NaN              Altstadt-Lehel
# 2                  NaN  Aubing-Lochhausen-Langwied

# %%
m_2309_geo.head(3)
# Out:
#                   neighbourhood neighbourhood_group  \
# 0                Altstadt-Lehel                None
# 1  Ludwigsvorstadt-Isarvorstadt                None
# 2                   Maxvorstadt                None
#
#                                             geometry
# 0  MULTIPOLYGON (((11.59520 48.14170, 11.59500 48...
# 1  MULTIPOLYGON (((11.55600 48.14080, 11.55930 48...
# 2  MULTIPOLYGON (((11.58430 48.14420, 11.58310 48...

# %%
for df in df_list:
    print("The dataframe {} has {} columns and {} rows".format([name for name, value in globals().items() if value is df][0], df.shape[1], df.shape[0]))
# Out:
# The dataframe m_2309_lst has 18 columns and 7336 rows
# The dataframe m_2309_lst2 has 75 columns and 7336 rows
# The dataframe m_2309_rvw has 2 columns and 160345 rows
# The dataframe m_2309_rvw2 has 6 columns and 160345 rows
# The dataframe m_2309_cal has 7 columns and 2677641 rows
# The dataframe m_2309_ngb has 2 columns and 25 rows
# The dataframe m_2309_geo has 3 columns and 25 rows

# %% [markdown]
# #### It seems like there are two versions of the files 'listings' and 'reviews'. Next, I want to check if they are similar and thus, if it possible to leave one of them out in the following steps.
# # Listings

# %%
# Check if column 'id' is unique
print(np.sum(m_2309_lst['id'].duplicated()))
print(np.sum(m_2309_lst2['id'].duplicated()))
# Out:
# 0
# 0

# %%
def compare_columns(df_1, df_2, col):
    df1 = df_1.sort_values(by = df_1.columns[0]).reset_index(drop=True)[[col]].add_suffix('_1')
    df2 = df_2.sort_values(by = df_2.columns[0]).reset_index(drop=True)[[col]].add_suffix('_2')

    comp_2_cols = pd.concat([df1, df2], axis = 1)
    comparison = np.sum((comp_2_cols.iloc[:,0] != comp_2_cols.iloc[:,1]))
    print('There are {} unequal values when comparing column {}.'.format(comparison, col))


for column in list(m_2309_lst.columns):
    try:
        compare_columns(m_2309_lst, m_2309_lst2, str(column))
    except:
        continue
# Out:
# There are 0 unequal values when comparing column id.
# There are 0 unequal values when comparing column name.
# There are 0 unequal values when comparing column host_id.
# There are 0 unequal values when comparing column host_name.
# There are 7336 unequal values when comparing column neighbourhood.
# There are 0 unequal values when comparing column latitude.
# There are 0 unequal values when comparing column longitude.
# There are 0 unequal values when comparing column room_type.
# There are 7336 unequal values when comparing column price.
# There are 0 unequal values when comparing column minimum_nights.
# There are 0 unequal values when comparing column number_of_reviews.
# There are 2027 unequal values when comparing column last_review.
# There are 2027 unequal values when comparing column reviews_per_month.
# There are 0 unequal values when comparing column calculated_host_listings_count.
# There are 0 unequal values when comparing column availability_365.
# There are 0 unequal values when comparing column number_of_reviews_ltm.
# There are 7315 unequal values when comparing column license.

# %% [markdown]
# #### Detailed check on the columns with deviations between the to datasets

# %%
df1 = m_2309_lst[['id','neighbourhood','price','last_review','reviews_per_month','license']].sort_values(by = 'id').reset_index(drop=True).add_suffix('_1')
df2 = m_2309_lst2[['id','neighbourhood', 'neighbourhood_cleansed','price','last_review','reviews_per_month','license']].sort_values(by = 'id').reset_index(drop=True).add_suffix('_2')
df1_df2 = pd.concat([df1, df2], axis = 1)
df1_df2
# Out:
# Empty DataFrame
# Columns: [id_1, neighbourhood_1, price_1, last_review_1, reviews_per_month_1, license_1, id_2, neighbourhood_2, neighbourhood_cleansed_2, price_2, last_review_2, reviews_per_month_2, license_2]
# Index: []

# %%
'''NEIGHBOURHOOD'''

#Find all columns that contain the string 'neighbourhood' in m_2309_lst2 to check if there is a better matching column
m_2309_lst2.filter(like = 'neighbourhood')

#Check unequal values again for column 'neighbourhood_cleansed' as it seems better 
df1 = m_2309_lst.sort_values(by = m_2309_lst.columns[0]).reset_index(drop=True)[['neighbourhood']].add_suffix('_1')
df2 = m_2309_lst2.sort_values(by = m_2309_lst.columns[0]).reset_index(drop=True)[['neighbourhood_cleansed']].add_suffix('_2')

comp_2_cols = pd.concat([df1, df2], axis = 1)
comparison = np.sum((comp_2_cols.iloc[:,0] != comp_2_cols.iloc[:,1]))
print('There are {} unequal values when comparing the two columns.'.format(comparison))

# Use neighbourhood_cleansed
# Out:
# There are 0 unequal values when comparing the two columns.

# %%
'''PRICE'''

#Check format of column "price" in both datasets
print(m_2309_lst['price'].dtypes)
print(m_2309_lst2['price'].dtypes)

#Create new column in enriched data set with a new column that converts price from object to integer
df1 = m_2309_lst.sort_values(by = m_2309_lst.columns[0]).reset_index(drop=True)[['price']].add_suffix('_1')
df2 = m_2309_lst2.sort_values(by = m_2309_lst.columns[0]).reset_index(drop=True)[['price']].add_suffix('_2')
df2['price_adj_format_2'] = df2['price_2'].str.replace('$','').str.split('.').str[0].str.replace(',','').astype(int)

comp_2_cols = pd.concat([df1, df2], axis = 1)
comparison = np.sum(comp_2_cols.iloc[:,0] != comp_2_cols.iloc[:,2])
print('There are {} unequal values when comparing the two columns.'.format(comparison))

# Use pice from first dataset
# Out:
# int64
# object
# There are 0 unequal values when comparing the two columns.

# %%
#LAST REVIEW
#Here it seems like the differences stem from a different formatting of the NaN values. 
#Lets see if there is differences after filtering out missing Values. 

print(np.sum(df1_df2['last_review_1'].isna()))

filtered_df = df1_df2[(df1_df2['last_review_1'] != df1_df2['last_review_2']) & (df1_df2['last_review_1'].notna())]
filtered_df
# >> as expected, all differences between the datasets come from a different formatting of the NaN entries
# Out:
# 2027
# Empty DataFrame
# Columns: [id_1, neighbourhood_1, price_1, last_review_1, reviews_per_month_1, license_1, id_2, neighbourhood_2, neighbourhood_cleansed_2, price_2, last_review_2, reviews_per_month_2, license_2]
# Index: []

# %%
#REVIEWS PER MONTH
print(np.sum(df1_df2['reviews_per_month_1'].isna()))

filtered_df = df1_df2[(df1_df2['reviews_per_month_1'] != df1_df2['reviews_per_month_2']) & (df1_df2['reviews_per_month_1'].notna())]
filtered_df
# >> as expected, all differences between the datasets come from a different formatting of the NaN entries
# Out:
# 2027
# Empty DataFrame
# Columns: [id_1, neighbourhood_1, price_1, last_review_1, reviews_per_month_1, license_1, id_2, neighbourhood_2, neighbourhood_cleansed_2, price_2, last_review_2, reviews_per_month_2, license_2]
# Index: []

# %%
#LICENSE
print(np.sum(df1_df2['license_1'].isna()))

filtered_df = df1_df2[(df1_df2['license_1'] != df1_df2['license_2']) & (df1_df2['license_1'].notna())]
filtered_df
# >> as expected, all differences between the datasets come from a different formatting of the NaN entries
# Out:
# 7315
# Empty DataFrame
# Columns: [id_1, neighbourhood_1, price_1, last_review_1, reviews_per_month_1, license_1, id_2, neighbourhood_2, neighbourhood_cleansed_2, price_2, last_review_2, reviews_per_month_2, license_2]
# Index: []

# %%
m_2309_lst_small = m_2309_lst
m_2309_lst = m_2309_lst2.drop('price',axis=1).merge(m_2309_lst_small[['id','price']], on='id', how='left')

print(np.sum(m_2309_lst_small['price']))
print(np.sum(m_2309_lst['price']))
# Out:
# 1678379
# 1678379

# %%
m_2309_lst.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  7.336000e+03  7.336000e+03  7.336000e+03          7336.000000
# mean   4.487728e+17  2.023092e+13  1.714005e+08             4.043893
# std    4.277424e+17  2.023575e+00  1.722905e+08            22.423907
# min    9.794500e+04  2.023092e+13  1.581000e+03             1.000000
# 25%    3.358451e+07  2.023092e+13  2.445032e+07             1.000000
# 50%    6.409723e+17  2.023092e+13  9.635626e+07             1.000000
# 75%    8.919355e+17  2.023092e+13  2.977107e+08             2.000000
# max    9.856358e+17  2.023092e+13  5.382086e+08           553.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                7336.000000  7336.000000  7336.000000   7336.000000
# mean                    5.063931    48.139473    11.561735      2.767176
# std                    25.067307     0.025375     0.048528      1.624050
# min                     1.000000    48.071440    11.388350      1.000000
# 25%                     1.000000    48.122827    11.538430      2.000000
# 50%                     2.000000    48.136970    11.563911      2.000000
# 75%                     3.000000    48.155327    11.585353      4.000000
# max                   620.000000    48.228020    11.712699     16.000000
#
#           bedrooms         beds  minimum_nights  maximum_nights  \
# count  4843.000000  7261.000000     7336.000000     7336.000000
# mean      1.350196     1.639306        7.489368      392.296210
# std       0.917730     1.342787       27.904934      432.854925
# min       1.000000     1.000000        1.000000        1.000000
# 25%       1.000000     1.000000        1.000000       26.000000
# 50%       1.000000     1.000000        2.000000      365.000000
# 75%       1.000000     2.000000        4.000000      365.000000
# max      27.000000    50.000000      999.000000     1125.000000
#
#        minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# count             7336.000000             7336.000000            7.336000e+03
# mean                 6.968239                8.135496            1.756879e+06
# std                 27.425471               28.765586            6.139424e+07
# min                  1.000000                1.000000            1.000000e+00
# 25%                  1.000000                1.000000            3.000000e+01
# 50%                  2.000000                2.000000            3.650000e+02
# 75%                  3.000000                4.000000            1.125000e+03
# max                999.000000              999.000000            2.147484e+09
#
#        maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# count            7.336000e+03             7336.000000            7.336000e+03
# mean             5.269679e+06                7.647628            2.711128e+06
# std              1.062509e+08               28.041129            7.153440e+07
# min              1.000000e+00                1.000000            1.000000e+00
# 25%              3.000000e+01                1.000000            3.000000e+01
# 50%              3.650000e+02                2.000000            3.650000e+02
# 75%              1.125000e+03                4.000000            1.125000e+03
# max              2.147484e+09              999.000000            2.147484e+09
#
#        availability_30  availability_60  availability_90  availability_365  \
# count      7336.000000      7336.000000      7336.000000       7336.000000
# mean          9.073882        20.761859        33.860687        115.054526
# std          10.067854        21.839150        34.203512        124.300011
# min           0.000000         0.000000         0.000000          0.000000
# 25%           0.000000         0.000000         0.000000          2.750000
# 50%           5.000000        11.000000        21.000000         66.000000
# 75%          18.000000        43.000000        70.000000        232.000000
# max          30.000000        60.000000        90.000000        365.000000
#
#        number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# count        7336.000000            7336.000000             7336.000000
# mean           21.857279               6.191521                0.592694
# std            66.261431              19.925587                1.580340
# min             0.000000               0.000000                0.000000
# 25%             0.000000               0.000000                0.000000
# 50%             3.000000               1.000000                0.000000
# 75%            14.000000               5.000000                1.000000
# max          1650.000000             740.000000               44.000000
#
#        review_scores_rating  review_scores_accuracy  \
# count           5318.000000             5308.000000
# mean               4.759579                4.804951
# std                0.453984                0.377354
# min                0.000000                1.000000
# 25%                4.690000                4.750000
# 50%                4.900000                4.930000
# 75%                5.000000                5.000000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                5308.000000            5308.000000
# mean                    4.719164               4.844563
# std                     0.470023               0.355328
# min                     1.000000               0.000000
# 25%                     4.640000               4.830000
# 50%                     4.890000               4.970000
# 75%                     5.000000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                  5308.000000             5308.000000
# mean                      4.855595                4.783745
# std                       0.337103                0.347854
# min                       1.000000                1.000000
# 25%                       4.850000                4.710000
# 50%                       5.000000                4.890000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count          5308.000000                     7336.000000
# mean              4.627924                        2.936478
# std               0.454651                        8.286522
# min               1.000000                        1.000000
# 25%               4.500000                        1.000000
# 50%               4.730000                        1.000000
# 75%               5.000000                        2.000000
# max               5.000000                       76.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  7336.000000
# mean                                      2.128135
# std                                       8.157963
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                      76.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   7336.000000
# mean                                       0.760496
# std                                        2.129617
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       26.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count                                  7336.000000        5309.000000
# mean                                      0.026445           1.010872
# std                                       0.261835           1.639296
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.190000
# 50%                                       0.000000           0.510000
# 75%                                       0.000000           1.120000
# max                                       5.000000          56.120000
#
#               price
# count   7336.000000
# mean     228.786668
# std     1155.948609
# min        9.000000
# 25%       92.000000
# 50%      150.000000
# 75%      250.000000
# max    96274.000000

# %%
# Drop columns with only missing values
m_2309_lst = m_2309_lst.drop(['neighbourhood_group_cleansed','bathrooms','calendar_updated'], axis=1)

# %% [markdown]
# # Reviews
# #### regarding the datasets m_2309_rvw and m_2309_rvw2 i will move forward with m_2309_rvw2 as it contains a lot more columns that are relevant

# %%
m_2309_rvw = m_2309_rvw2
m_2309_rvw2.describe()
# Out:
#          listing_id            id   reviewer_id
# count  1.603450e+05  1.603450e+05  1.603450e+05
# mean   8.083320e+16  3.628587e+17  1.511716e+08
# std    2.319025e+17  3.910768e+17  1.460039e+08
# min    9.794500e+04  2.976850e+05  1.000000e+00
# 25%    5.702154e+06  3.207912e+08  3.217967e+07
# 50%    2.068520e+07  7.259416e+08  9.972980e+07
# 75%    4.045921e+07  7.454135e+17  2.300618e+08
# max    9.825751e+17  9.861474e+17  5.378926e+08

# %% [markdown]
# # Calendar

# %%
m_2309_cal.describe()
m_2309_cal['available'].value_counts()
print(m_2309_cal.shape)

compare_price = np.sum(m_2309_cal['price'] != m_2309_cal['adjusted_price'])
print('There are {} unequal values when comparing the two columns.'.format(compare_price))
print('There are {} missing values in the price column'.format(np.sum(m_2309_cal['price'].isna())))
# Out:
# (2677641, 7)
# There are 66238 unequal values when comparing the two columns.
# There are 0 missing values in the price column

# %%
#Check for differences in the price columns

m_2309_cal[['price','adjusted_price']][m_2309_cal['price'] != m_2309_cal['adjusted_price']]

#the price column seems to differ from the adjusted price column for a reason >> keep both
# Out:
#            price adjusted_price
# 3650      $85.00         $78.00
# 3651      $85.00         $78.00
# 3652      $85.00         $78.00
# 17885     $58.00         $55.00
# 17886     $58.00         $55.00
# ...          ...            ...
# 2660121  $120.00         $84.00
# 2660122  $120.00         $84.00
# 2660123  $120.00         $84.00
# 2669611   $45.00         $36.00
# 2669612   $45.00         $36.00
#
# [66238 rows x 2 columns]

# %% [markdown]
# # Neighbourhoods

# %%
m_2309_ngb
m_2309_ngb['neighbourhood_group'].value_counts()

# dataset will be dropped from the analysis
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# # Neighbourhoods Geo

# %%
m_2309_geo
m_2309_geo['neighbourhood_group'].value_counts()
m_2309_geo.drop('neighbourhood_group', axis=1)
# Out:
#                                         neighbourhood  \
# 0                                      Altstadt-Lehel
# 1                        Ludwigsvorstadt-Isarvorstadt
# 2                                         Maxvorstadt
# 3                                      Schwabing-West
# 4                                       Au-Haidhausen
# 5                                            Sendling
# 6                                   Sendling-Westpark
# 7                                    Schwanthalerhöhe
# 8                               Neuhausen-Nymphenburg
# 9                                             Moosach
# 10                              Milbertshofen-Am Hart
# 11                                 Schwabing-Freimann
# 12                                        Bogenhausen
# 13                                       Berg am Laim
# 14                                      Tudering-Riem
# 15                                 Ramersdorf-Perlach
# 16                                        Obergiesing
# 17                            Untergiesing-Harlaching
# 18  Thalkirchen-Obersendling-Forstenried-Fürstenri...
# 19                                             Hadern
# 20                                 Pasing-Obermenzing
# 21                         Aubing-Lochhausen-Langwied
# 22                                Allach-Untermenzing
# 23                             Feldmoching-Hasenbergl
# 24                                               Laim
#
#                                              geometry
# 0   MULTIPOLYGON (((11.59520 48.14170, 11.59500 48...
# 1   MULTIPOLYGON (((11.55600 48.14080, 11.55930 48...
# 2   MULTIPOLYGON (((11.58430 48.14420, 11.58310 48...
# 3   MULTIPOLYGON (((11.58170 48.17630, 11.58320 48...
# 4   MULTIPOLYGON (((11.59560 48.14050, 11.59590 48...
# 5   MULTIPOLYGON (((11.55290 48.10600, 11.55180 48...
# 6   MULTIPOLYGON (((11.53790 48.12650, 11.53770 48...
# 7   MULTIPOLYGON (((11.53460 48.14250, 11.53880 48...
# 8   MULTIPOLYGON (((11.54810 48.17080, 11.55010 48...
# 9   MULTIPOLYGON (((11.53300 48.18870, 11.53470 48...
# 10  MULTIPOLYGON (((11.58300 48.22760, 11.58430 48...
# 11  MULTIPOLYGON (((11.62640 48.22880, 11.62830 48...
# 12  MULTIPOLYGON (((11.66680 48.18240, 11.67180 48...
# 13  MULTIPOLYGON (((11.60220 48.12390, 11.60360 48...
# 14  MULTIPOLYGON (((11.67820 48.14440, 11.67820 48...
# 15  MULTIPOLYGON (((11.60400 48.12270, 11.60610 48...
# 16  MULTIPOLYGON (((11.60070 48.10190, 11.60420 48...
# 17  MULTIPOLYGON (((11.58180 48.10430, 11.58190 48...
# 18  MULTIPOLYGON (((11.54810 48.10570, 11.55110 48...
# 19  MULTIPOLYGON (((11.47800 48.13050, 11.48300 48...
# 20  MULTIPOLYGON (((11.46020 48.17620, 11.46460 48...
# 21  MULTIPOLYGON (((11.43180 48.20510, 11.43250 48...
# 22  MULTIPOLYGON (((11.48260 48.20990, 11.48280 48...
# 23  MULTIPOLYGON (((11.50560 48.24740, 11.50620 48...
# 24  MULTIPOLYGON (((11.51310 48.14380, 11.51900 48...

# %% [markdown]
# # Join relevant datasets

# %%
m_2309_geo.rename(columns={'neighbourhood': 'neighbourhood_cleansed'}, inplace=True)

m_2309_lst = m_2309_lst.merge(m_2309_geo[['neighbourhood_cleansed','geometry']], on ='neighbourhood_cleansed', how='left')
m_2309_lst
# Out:
#                       id                                      listing_url  \
# 0                  97945               https://www.airbnb.com/rooms/97945
# 1                 114695              https://www.airbnb.com/rooms/114695
# 2                 127383              https://www.airbnb.com/rooms/127383
# 3                 159634              https://www.airbnb.com/rooms/159634
# 4                 170154              https://www.airbnb.com/rooms/170154
# ...                  ...                                              ...
# 7331  985458300606098774  https://www.airbnb.com/rooms/985458300606098774
# 7332  985461390228462817  https://www.airbnb.com/rooms/985461390228462817
# 7333  985564160370949842  https://www.airbnb.com/rooms/985564160370949842
# 7334  985581865419521485  https://www.airbnb.com/rooms/985581865419521485
# 7335  985635822997105713  https://www.airbnb.com/rooms/985635822997105713
#
#            scrape_id last_scraped           source  \
# 0     20230922223227   2023-09-23      city scrape
# 1     20230922223227   2023-09-23      city scrape
# 2     20230922223227   2023-09-23  previous scrape
# 3     20230922223227   2023-09-23      city scrape
# 4     20230922223227   2023-09-23      city scrape
# ...              ...          ...              ...
# 7331  20230922223227   2023-09-23      city scrape
# 7332  20230922223227   2023-09-23      city scrape
# 7333  20230922223227   2023-09-23      city scrape
# 7334  20230922223227   2023-09-23      city scrape
# 7335  20230922223227   2023-09-23      city scrape
#
#                                                    name  \
# 0     Rental unit in Munich · ★4.84 · 1 bedroom · 1 ...
# 1     Rental unit in Munich · ★4.80 · 1 bedroom · 3 ...
# 2     Rental unit in Munich · ★4.83 · 1 bedroom · 1 ...
# 3     Rental unit in Munich · ★4.63 · 1 bedroom · 1 ...
# 4     Home in Munich · ★4.95 · 1 bedroom · 2 beds · ...
# ...                                                 ...
# 7331  Rental unit in Munich · ★New · 1 bedroom · 1 b...
# 7332  Rental unit in Munich · ★New · 1 bedroom · 1 b...
# 7333  Rental unit in Munich · ★New · 1 bedroom · 1 b...
# 7334  Condo in Munich · ★New · 3 bedrooms · 4 beds ·...
# 7335  Rental unit in Munich · ★New · 1 bedroom · 1 b...
#
#                                             description  \
# 0     <b>The space</b><br />We offer a modern, quiet...
# 1     <b>The space</b><br />It´s a quiet and sunny a...
# 2     <b>The space</b><br />My cosy apartment is loc...
# 3     In this idyllic stylish flat you live very qui...
# 4     Enjoy a quiet neighbourhood, easy access to th...
# ...                                                 ...
# 7331  We offer a modernly furnished apartment in the...
# 7332  Gemütliches Zimmer in München Zentrum in eine ...
# 7333  Genieße ein stilvolles Erlebnis in dieser zent...
# 7334  From this centrally located accommodation you ...
# 7335  Cosy and chill place to stay :-)<br /><br /><b...
#
#                                   neighborhood_overview  \
# 0     We are living in a outskirt of Munich its call...
# 1                                                   NaN
# 2                                                   NaN
# 3     Very quiet, green, squirrels and beergardens a...
# 4                                                   NaN
# ...                                                 ...
# 7331                                                NaN
# 7332                                                NaN
# 7333                                                NaN
# 7334                                                NaN
# 7335  Die Nachbarschaft um den Goetheplatz in Münche...
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/2459996/10b4c...     517685
# 1     https://a0.muscache.com/pictures/21571874/960e...     581737
# 2     https://a0.muscache.com/pictures/79238c11-bc61...     630556
# 3     https://a0.muscache.com/pictures/72bdd2e1-914e...     765694
# 4     https://a0.muscache.com/pictures/31636890/593e...     108297
# ...                                                 ...        ...
# 7331  https://a0.muscache.com/pictures/miso/Hosting-...   35237686
# 7332  https://a0.muscache.com/pictures/02f4017f-2bce...  112522956
# 7333  https://a0.muscache.com/pictures/d091445c-fdbf...  516732437
# 7334  https://a0.muscache.com/pictures/miso/Hosting-...   87189348
# 7335  https://a0.muscache.com/pictures/miso/Hosting-...   23562505
#
#                                          host_url host_name  host_since  \
# 0        https://www.airbnb.com/users/show/517685  Angelika  2011-04-18
# 1        https://www.airbnb.com/users/show/581737   Stephan  2011-05-12
# 2        https://www.airbnb.com/users/show/630556     Sonja  2011-05-26
# 3        https://www.airbnb.com/users/show/765694    Susana  2011-07-01
# 4        https://www.airbnb.com/users/show/108297      Alex  2010-04-14
# ...                                           ...       ...         ...
# 7331   https://www.airbnb.com/users/show/35237686      Sibu  2015-06-07
# 7332  https://www.airbnb.com/users/show/112522956     Morty  2017-01-21
# 7333  https://www.airbnb.com/users/show/516732437  Johannes  2023-05-26
# 7334   https://www.airbnb.com/users/show/87189348    Marvin  2016-08-01
# 7335   https://www.airbnb.com/users/show/23562505      Inga  2014-11-10
#
#         host_location                                         host_about  \
# 0     Munich, Germany  Ich freue mich auf viele internationale Gäste!...
# 1     Munich, Germany  I am looking forward to meet interesting peopl...
# 2     Munich, Germany  Hi, mein Name ist Sonja und ich freue mich net...
# 3     Munich, Germany  outdoorsy sportive Person from Munich. I love ...
# 4     Munich, Germany  We love to travel and dream of living in a hou...
# ...               ...                                                ...
# 7331  Munich, Germany                                   Together we grow
# 7332  Munich, Germany                                                NaN
# 7333  Munich, Germany                                                NaN
# 7334  Munich, Germany  Young Working professional currently leading a...
# 7335  Munich, Germany  Hallo, ich lebe im zauberhaften und grünen Mün...
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0           within a day                75%                   0%
# 1         within an hour               100%                  86%
# 2         within an hour               100%                  75%
# 3         within an hour               100%                 100%
# 4     within a few hours               100%                  96%
# ...                  ...                ...                  ...
# 7331                 NaN                NaN                  NaN
# 7332      within an hour               100%                 100%
# 7333                 NaN                NaN                  NaN
# 7334                 NaN                NaN                  83%
# 7335                 NaN                NaN                  NaN
#
#      host_is_superhost                                 host_thumbnail_url  \
# 0                    f  https://a0.muscache.com/im/users/517685/profil...
# 1                    t  https://a0.muscache.com/im/users/581737/profil...
# 2                    f  https://a0.muscache.com/im/users/630556/profil...
# 3                    f  https://a0.muscache.com/im/pictures/user/8bd96...
# 4                    t  https://a0.muscache.com/im/pictures/user/38794...
# ...                ...                                                ...
# 7331                 f  https://a0.muscache.com/im/pictures/user/User-...
# 7332                 f  https://a0.muscache.com/im/pictures/user/User-...
# 7333                 f  https://a0.muscache.com/im/pictures/user/User-...
# 7334                 f  https://a0.muscache.com/im/pictures/user/b728a...
# 7335                 f  https://a0.muscache.com/im/pictures/user/User-...
#
#                                        host_picture_url    host_neighbourhood  \
# 0     https://a0.muscache.com/im/users/517685/profil...                Hadern
# 1     https://a0.muscache.com/im/users/581737/profil...          Berg am Laim
# 2     https://a0.muscache.com/im/users/630556/profil...           Maxvorstadt
# 3     https://a0.muscache.com/im/pictures/user/8bd96...  Pasing - Obermenzing
# 4     https://a0.muscache.com/im/pictures/user/38794...   Sendling - Westpark
# ...                                                 ...                   ...
# 7331  https://a0.muscache.com/im/pictures/user/User-...                   NaN
# 7332  https://a0.muscache.com/im/pictures/user/User-...                   NaN
# 7333  https://a0.muscache.com/im/pictures/user/User-...                   NaN
# 7334  https://a0.muscache.com/im/pictures/user/b728a...                   NaN
# 7335  https://a0.muscache.com/im/pictures/user/User-...                   NaN
#
#       host_listings_count  host_total_listings_count  \
# 0                       2                          3
# 1                       3                          3
# 2                       2                          2
# 3                       1                          1
# 4                       1                          1
# ...                   ...                        ...
# 7331                    1                          1
# 7332                    4                          5
# 7333                    1                          1
# 7334                    1                          3
# 7335                    1                          1
#
#                     host_verifications host_has_profile_pic  \
# 0                   ['email', 'phone']                    t
# 1                   ['email', 'phone']                    t
# 2     ['email', 'phone', 'work_email']                    t
# 3                   ['email', 'phone']                    t
# 4                   ['email', 'phone']                    t
# ...                                ...                  ...
# 7331                ['email', 'phone']                    t
# 7332                ['email', 'phone']                    t
# 7333                         ['phone']                    t
# 7334  ['email', 'phone', 'work_email']                    t
# 7335                         ['phone']                    t
#
#      host_identity_verified           neighbourhood_x  \
# 0                         t  Munich, Bavaria, Germany
# 1                         t                       NaN
# 2                         t                       NaN
# 3                         t  Munich, Bavaria, Germany
# 4                         t                       NaN
# ...                     ...                       ...
# 7331                      t                       NaN
# 7332                      t                       NaN
# 7333                      t                       NaN
# 7334                      t                       NaN
# 7335                      t   Munich, Bayern, Germany
#
#             neighbourhood_cleansed   latitude  longitude  \
# 0                           Hadern  48.114920  11.489540
# 1                     Berg am Laim  48.120710  11.637580
# 2                      Maxvorstadt  48.151990  11.564820
# 3               Pasing-Obermenzing  48.138550  11.465860
# 4                Sendling-Westpark  48.108140  11.527330
# ...                            ...        ...        ...
# 7331                Altstadt-Lehel  48.137030  11.582830
# 7332            Ramersdorf-Perlach  48.107861  11.636754
# 7333  Ludwigsvorstadt-Isarvorstadt  48.129599  11.575034
# 7334            Schwabing-Freimann  48.159314  11.583234
# 7335  Ludwigsvorstadt-Isarvorstadt  48.128438  11.559181
#
#                     property_type        room_type  accommodates  \
# 0              Entire rental unit  Entire home/apt             2
# 1              Entire rental unit  Entire home/apt             5
# 2              Entire rental unit  Entire home/apt             4
# 3              Entire rental unit  Entire home/apt             2
# 4            Private room in home     Private room             4
# ...                           ...              ...           ...
# 7331           Entire rental unit  Entire home/apt             2
# 7332  Private room in rental unit     Private room             2
# 7333  Private room in rental unit     Private room             2
# 7334                 Entire condo  Entire home/apt             6
# 7335           Entire rental unit  Entire home/apt             2
#
#      bathrooms_text  bedrooms  beds  \
# 0            1 bath       1.0   1.0
# 1            1 bath       1.0   3.0
# 2            1 bath       1.0   1.0
# 3            1 bath       1.0   1.0
# 4     1 shared bath       NaN   2.0
# ...             ...       ...   ...
# 7331         1 bath       1.0   1.0
# 7332         1 bath       1.0   1.0
# 7333         1 bath       1.0   1.0
# 7334        3 baths       3.0   4.0
# 7335         1 bath       1.0   1.0
#
#                                               amenities  minimum_nights  \
# 0     ["Heating", "Paid dryer", "Oven", "Room-darken...               2
# 1     ["Heating", "Oven", "Smoke alarm", "Cooking ba...               1
# 2     ["Heating", "Breakfast", "Private patio or bal...               3
# 3     ["Free washer \u2013 In building", "30\" HDTV ...               5
# 4     ["Heating", "Breakfast", "Oven", "Pets allowed...               3
# ...                                                 ...             ...
# 7331  ["Paid street parking off premises", "Courtyar...               3
# 7332  ["Shampoo", "Heating", "Hair dryer", "Dishes a...               1
# 7333  ["Hair dryer", "Courtyard view", "Washer", "Wi...               1
# 7334  ["Cooking basics", "Dishes and silverware", "B...               1
# 7335  ["Washer", "Dedicated workspace", "Host greets...               2
#
#       maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0                 90                       2                       2
# 1                 30                       1                       1
# 2                 14                       3                       3
# 3                 35                       7                       7
# 4               1125                       3                       3
# ...              ...                     ...                     ...
# 7331             365                       3                       3
# 7332             365                       1                       1
# 7333              14                       1                       1
# 7334             365                       1                       1
# 7335             365                       2                       2
#
#       minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                         90                      90                     2.0
# 1                         30                      30                     1.0
# 2                         14                      14                     3.0
# 3                       1125                    1125                     7.0
# 4                       1125                    1125                     3.0
# ...                      ...                     ...                     ...
# 7331                     365                     365                     3.0
# 7332                     365                     365                     1.0
# 7333                    1125                    1125                     1.0
# 7334                     365                     365                     1.0
# 7335                     365                     365                     2.0
#
#       maximum_nights_avg_ntm has_availability  availability_30  \
# 0                       90.0                t                1
# 1                       30.0                t               18
# 2                       14.0                t                0
# 3                     1125.0                t                2
# 4                     1125.0                t                0
# ...                      ...              ...              ...
# 7331                   365.0                t               29
# 7332                   365.0                t               23
# 7333                  1125.0                t               30
# 7334                   365.0                t               27
# 7335                   365.0                t               30
#
#       availability_60  availability_90  availability_365  \
# 0                   1                1                89
# 1                  27               27               106
# 2                   0                0                 0
# 3                   2                2                 2
# 4                   1               13               155
# ...               ...              ...               ...
# 7331               59               89               269
# 7332               53               83               263
# 7333               60               90               180
# 7334               57               87                87
# 7335               60               90                90
#
#      calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# 0               2023-09-23                129                      0
# 1               2023-09-23                 60                      5
# 2               2023-09-23                108                      1
# 3               2023-09-23                 39                      4
# 4               2023-09-23                538                     22
# ...                    ...                ...                    ...
# 7331            2023-09-23                  0                      0
# 7332            2023-09-23                  0                      0
# 7333            2023-09-23                  0                      0
# 7334            2023-09-23                  0                      0
# 7335            2023-09-23                  0                      0
#
#       number_of_reviews_l30d first_review last_review  review_scores_rating  \
# 0                          0   2011-10-03  2019-10-03                  4.84
# 1                          1   2011-07-08  2023-09-19                  4.80
# 2                          0   2011-06-04  2023-07-29                  4.83
# 3                          0   2011-08-15  2023-08-09                  4.63
# 4                          2   2011-09-25  2023-09-18                  4.95
# ...                      ...          ...         ...                   ...
# 7331                       0          NaN         NaN                   NaN
# 7332                       0          NaN         NaN                   NaN
# 7333                       0          NaN         NaN                   NaN
# 7334                       0          NaN         NaN                   NaN
# 7335                       0          NaN         NaN                   NaN
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                       4.89                       4.82
# 1                       4.75                       4.97
# 2                       4.91                       4.79
# 3                       4.73                       4.24
# 4                       4.95                       4.98
# ...                      ...                        ...
# 7331                     NaN                        NaN
# 7332                     NaN                        NaN
# 7333                     NaN                        NaN
# 7334                     NaN                        NaN
# 7335                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 0                      4.90                         4.93
# 1                      4.97                         5.00
# 2                      4.98                         4.95
# 3                      4.76                         4.78
# 4                      4.99                         4.98
# ...                     ...                          ...
# 7331                    NaN                          NaN
# 7332                    NaN                          NaN
# 7333                    NaN                          NaN
# 7334                    NaN                          NaN
# 7335                    NaN                          NaN
#
#       review_scores_location  review_scores_value license instant_bookable  \
# 0                       4.78                 4.73     NaN                f
# 1                       4.58                 4.60     NaN                f
# 2                       4.91                 4.79     NaN                f
# 3                       4.54                 4.41     NaN                t
# 4                       4.77                 4.91     NaN                f
# ...                      ...                  ...     ...              ...
# 7331                     NaN                  NaN     NaN                f
# 7332                     NaN                  NaN     NaN                t
# 7333                     NaN                  NaN     NaN                f
# 7334                     NaN                  NaN     NaN                t
# 7335                     NaN                  NaN     NaN                t
#
#       calculated_host_listings_count  \
# 0                                  2
# 1                                  3
# 2                                  1
# 3                                  1
# 4                                  1
# ...                              ...
# 7331                               1
# 7332                               4
# 7333                               1
# 7334                               1
# 7335                               1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               2
# 1                                               3
# 2                                               1
# 3                                               1
# 4                                               0
# ...                                           ...
# 7331                                            1
# 7332                                            1
# 7333                                            0
# 7334                                            1
# 7335                                            1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                1
# ...                                            ...
# 7331                                             0
# 7332                                             3
# 7333                                             1
# 7334                                             0
# 7335                                             0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  price  \
# 0                                               0               0.88     97
# 1                                               0               0.40    111
# 2                                               0               0.72    120
# 3                                               0               0.26     90
# 4                                               0               3.68    120
# ...                                           ...                ...    ...
# 7331                                            0                NaN    260
# 7332                                            0                NaN     70
# 7333                                            0                NaN    150
# 7334                                            0                NaN    342
# 7335                                            0                NaN    193
#
#                    neighbourhood_y  \
# 0                           Hadern
# 1                     Berg am Laim
# 2                      Maxvorstadt
# 3               Pasing-Obermenzing
# 4                Sendling-Westpark
# ...                            ...
# 7331                Altstadt-Lehel
# 7332            Ramersdorf-Perlach
# 7333  Ludwigsvorstadt-Isarvorstadt
# 7334            Schwabing-Freimann
# 7335  Ludwigsvorstadt-Isarvorstadt
#
#                                              geometry_x  \
# 0     MULTIPOLYGON (((11.47800 48.13050, 11.48300 48...
# 1     MULTIPOLYGON (((11.60220 48.12390, 11.60360 48...
# 2     MULTIPOLYGON (((11.58430 48.14420, 11.58310 48...
# 3     MULTIPOLYGON (((11.46020 48.17620, 11.46460 48...
# 4     MULTIPOLYGON (((11.53790 48.12650, 11.53770 48...
# ...                                                 ...
# 7331  MULTIPOLYGON (((11.59520 48.14170, 11.59500 48...
# 7332  MULTIPOLYGON (((11.60400 48.12270, 11.60610 48...
# 7333  MULTIPOLYGON (((11.55600 48.14080, 11.55930 48...
# 7334  MULTIPOLYGON (((11.62640 48.22880, 11.62830 48...
# 7335  MULTIPOLYGON (((11.55600 48.14080, 11.55930 48...
#
#                      neighbourhood  \
# 0                           Hadern
# 1                     Berg am Laim
# 2                      Maxvorstadt
# 3               Pasing-Obermenzing
# 4                Sendling-Westpark
# ...                            ...
# 7331                Altstadt-Lehel
# 7332            Ramersdorf-Perlach
# 7333  Ludwigsvorstadt-Isarvorstadt
# 7334            Schwabing-Freimann
# 7335  Ludwigsvorstadt-Isarvorstadt
#
#                                              geometry_y  \
# 0     MULTIPOLYGON (((11.47800 48.13050, 11.48300 48...
# 1     MULTIPOLYGON (((11.60220 48.12390, 11.60360 48...
# 2     MULTIPOLYGON (((11.58430 48.14420, 11.58310 48...
# 3     MULTIPOLYGON (((11.46020 48.17620, 11.46460 48...
# 4     MULTIPOLYGON (((11.53790 48.12650, 11.53770 48...
# ...                                                 ...
# 7331  MULTIPOLYGON (((11.59520 48.14170, 11.59500 48...
# 7332  MULTIPOLYGON (((11.60400 48.12270, 11.60610 48...
# 7333  MULTIPOLYGON (((11.55600 48.14080, 11.55930 48...
# 7334  MULTIPOLYGON (((11.62640 48.22880, 11.62830 48...
# 7335  MULTIPOLYGON (((11.55600 48.14080, 11.55930 48...
#
#                                                geometry
# 0     MULTIPOLYGON (((11.47800 48.13050, 11.48300 48...
# 1     MULTIPOLYGON (((11.60220 48.12390, 11.60360 48...
# 2     MULTIPOLYGON (((11.58430 48.14420, 11.58310 48...
# 3     MULTIPOLYGON (((11.46020 48.17620, 11.46460 48...
# 4     MULTIPOLYGON (((11.53790 48.12650, 11.53770 48...
# ...                                                 ...
# 7331  MULTIPOLYGON (((11.59520 48.14170, 11.59500 48...
# 7332  MULTIPOLYGON (((11.60400 48.12270, 11.60610 48...
# 7333  MULTIPOLYGON (((11.55600 48.14080, 11.55930 48...
# 7334  MULTIPOLYGON (((11.62640 48.22880, 11.62830 48...
# 7335  MULTIPOLYGON (((11.55600 48.14080, 11.55930 48...
#
# [7336 rows x 77 columns]

# %% [markdown]
# ## Final datasets for further analysis
#
# ### 1. m_2309_lst
# ### 2. m_2309_rvw
# ### 3. m_2309_cal
#
# #### Drop: m_2309_lst (small version), m_2309_rvw (small version), m_2309_geo (joined), m_2309_ngb (no value added)
